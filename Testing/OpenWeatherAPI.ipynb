# %%
import requests

# %%
api_url = 'https://api.openweathermap.org/data/3.0/onecall?lat=6.23&lon=80.05&appid=59632c44384fd3104ed01ce7f3510d50'

# %%
response = requests.get(api_url)

# %%
response.json()
# Out:
# {'lat': 6.23,
#  'lon': 80.05,
#  'timezone': 'Asia/Colombo',
#  'timezone_offset': 19800,
#  'current': {'dt': 1718050845,
#   'sunrise': 1718065515,
#   'sunset': 1718110433,
#   'temp': 302.11,
#   'feels_like': 308.44,
#   'pressure': 1011,
#   'humidity': 83,
#   'dew_point': 298.93,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 6.03,
#   'wind_deg': 256,
#   'wind_gust': 8.61,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}]},
#  'minutely': [{'dt': 1718050860, 'precipitation': 0},
#   {'dt': 1718050920, 'precipitation': 0},
#   {'dt': 1718050980, 'precipitation': 0},
#   {'dt': 1718051040, 'precipitation': 0},
#   {'dt': 1718051100, 'precipitation': 0},
#   {'dt': 1718051160, 'precipitation': 0},
#   {'dt': 1718051220, 'precipitation': 0},
#   {'dt': 1718051280, 'precipitation': 0},
#   {'dt': 1718051340, 'precipitation': 0},
#   {'dt': 1718051400, 'precipitation': 0},
#   {'dt': 1718051460, 'precipitation': 0},
#   {'dt': 1718051520, 'precipitation': 0},
#   {'dt': 1718051580, 'precipitation': 0},
#   {'dt': 1718051640, 'precipitation': 0},
#   {'dt': 1718051700, 'precipitation': 0},
#   {'dt': 1718051760, 'precipitation': 0},
#   {'dt': 1718051820, 'precipitation': 0},
#   {'dt': 1718051880, 'precipitation': 0},
#   {'dt': 1718051940, 'precipitation': 0},
#   {'dt': 1718052000, 'precipitation': 0},
#   {'dt': 1718052060, 'precipitation': 0},
#   {'dt': 1718052120, 'precipitation': 0},
#   {'dt': 1718052180, 'precipitation': 0},
#   {'dt': 1718052240, 'precipitation': 0},
#   {'dt': 1718052300, 'precipitation': 0},
#   {'dt': 1718052360, 'precipitation': 0},
#   {'dt': 1718052420, 'precipitation': 0},
#   {'dt': 1718052480, 'precipitation': 0},
#   {'dt': 1718052540, 'precipitation': 0},
#   {'dt': 1718052600, 'precipitation': 0},
#   {'dt': 1718052660, 'precipitation': 0},
#   {'dt': 1718052720, 'precipitation': 0},
#   {'dt': 1718052780, 'precipitation': 0},
#   {'dt': 1718052840, 'precipitation': 0},
#   {'dt': 1718052900, 'precipitation': 0},
#   {'dt': 1718052960, 'precipitation': 0},
#   {'dt': 1718053020, 'precipitation': 0},
#   {'dt': 1718053080, 'precipitation': 0},
#   {'dt': 1718053140, 'precipitation': 0},
#   {'dt': 1718053200, 'precipitation': 0},
#   {'dt': 1718053260, 'precipitation': 0},
#   {'dt': 1718053320, 'precipitation': 0},
#   {'dt': 1718053380, 'precipitation': 0},
#   {'dt': 1718053440, 'precipitation': 0},
#   {'dt': 1718053500, 'precipitation': 0},
#   {'dt': 1718053560, 'precipitation': 0},
#   {'dt': 1718053620, 'precipitation': 0},
#   {'dt': 1718053680, 'precipitation': 0},
#   {'dt': 1718053740, 'precipitation': 0},
#   {'dt': 1718053800, 'precipitation': 0},
#   {'dt': 1718053860, 'precipitation': 0},
#   {'dt': 1718053920, 'precipitation': 0},
#   {'dt': 1718053980, 'precipitation': 0},
#   {'dt': 1718054040, 'precipitation': 0},
#   {'dt': 1718054100, 'precipitation': 0},
#   {'dt': 1718054160, 'precipitation': 0},
#   {'dt': 1718054220, 'precipitation': 0},
#   {'dt': 1718054280, 'precipitation': 0},
#   {'dt': 1718054340, 'precipitation': 0},
#   {'dt': 1718054400, 'precipitation': 0}],
#  'hourly': [{'dt': 1718049600,
#    'temp': 302.11,
#    'feels_like': 308.44,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 298.93,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.03,
#    'wind_deg': 256,
#    'wind_gust': 8.61,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.52,
#    'rain': {'1h': 0.47}},
#   {'dt': 1718053200,
#    'temp': 301.79,
#    'feels_like': 307.5,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 298.62,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.16,
#    'wind_deg': 253,
#    'wind_gust': 8.36,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.59},
#   {'dt': 1718056800,
#    'temp': 301.46,
#    'feels_like': 306.57,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 298.29,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.45,
#    'wind_deg': 257,
#    'wind_gust': 9.08,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.56},
#   {'dt': 1718060400,
#    'temp': 301.11,
#    'feels_like': 305.61,
#    'pressure': 1010,
#    'humidity': 83,
#    'dew_point': 297.95,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.37,
#    'wind_deg': 250,
#    'wind_gust': 8.96,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.63,
#    'rain': {'1h': 0.61}},
#   {'dt': 1718064000,
#    'temp': 300.83,
#    'feels_like': 304.88,
#    'pressure': 1010,
#    'humidity': 83,
#    'dew_point': 297.68,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 6.46,
#    'wind_deg': 250,
#    'wind_gust': 9.16,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.59,
#    'rain': {'1h': 0.16}},
#   {'dt': 1718067600,
#    'temp': 300.63,
#    'feels_like': 304.36,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 297.4,
#    'uvi': 0.15,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 7.01,
#    'wind_deg': 251,
#    'wind_gust': 9.71,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.53,
#    'rain': {'1h': 0.13}},
#   {'dt': 1718071200,
#    'temp': 301.02,
#    'feels_like': 305.07,
#    'pressure': 1011,
#    'humidity': 81,
#    'dew_point': 297.47,
#    'uvi': 0.92,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 7.18,
#    'wind_deg': 249,
#    'wind_gust': 9.51,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.55,
#    'rain': {'1h': 0.12}},
#   {'dt': 1718074800,
#    'temp': 301.48,
#    'feels_like': 306.09,
#    'pressure': 1012,
#    'humidity': 80,
#    'dew_point': 297.67,
#    'uvi': 2.9,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 7.33,
#    'wind_deg': 248,
#    'wind_gust': 9.48,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.55,
#    'rain': {'1h': 0.39}},
#   {'dt': 1718078400,
#    'temp': 301.75,
#    'feels_like': 306.61,
#    'pressure': 1012,
#    'humidity': 79,
#    'dew_point': 297.66,
#    'uvi': 5.68,
#    'clouds': 79,
#    'visibility': 10000,
#    'wind_speed': 7.62,
#    'wind_deg': 249,
#    'wind_gust': 9.5,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.55,
#    'rain': {'1h': 0.47}},
#   {'dt': 1718082000,
#    'temp': 301.89,
#    'feels_like': 306.98,
#    'pressure': 1012,
#    'humidity': 79,
#    'dew_point': 297.78,
#    'uvi': 8.83,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 7.81,
#    'wind_deg': 250,
#    'wind_gust': 9.65,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.62,
#    'rain': {'1h': 0.5}},
#   {'dt': 1718085600,
#    'temp': 301.93,
#    'feels_like': 307.08,
#    'pressure': 1011,
#    'humidity': 79,
#    'dew_point': 297.8,
#    'uvi': 11.08,
#    'clouds': 66,
#    'visibility': 10000,
#    'wind_speed': 8.33,
#    'wind_deg': 252,
#    'wind_gust': 10.23,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.55,
#    'rain': {'1h': 0.64}},
#   {'dt': 1718089200,
#    'temp': 302.02,
#    'feels_like': 307.12,
#    'pressure': 1011,
#    'humidity': 78,
#    'dew_point': 297.83,
#    'uvi': 11.52,
#    'clouds': 49,
#    'visibility': 10000,
#    'wind_speed': 7.91,
#    'wind_deg': 253,
#    'wind_gust': 9.72,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.69,
#    'rain': {'1h': 0.65}},
#   {'dt': 1718092800,
#    'temp': 301.88,
#    'feels_like': 306.76,
#    'pressure': 1010,
#    'humidity': 78,
#    'dew_point': 297.71,
#    'uvi': 9.44,
#    'clouds': 74,
#    'visibility': 10000,
#    'wind_speed': 7.79,
#    'wind_deg': 255,
#    'wind_gust': 9.64,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.91,
#    'rain': {'1h': 0.89}},
#   {'dt': 1718096400,
#    'temp': 301.73,
#    'feels_like': 306.56,
#    'pressure': 1010,
#    'humidity': 79,
#    'dew_point': 297.72,
#    'uvi': 6.97,
#    'clouds': 77,
#    'visibility': 10000,
#    'wind_speed': 7.65,
#    'wind_deg': 254,
#    'wind_gust': 9.44,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.96,
#    'rain': {'1h': 1.01}},
#   {'dt': 1718100000,
#    'temp': 301.42,
#    'feels_like': 305.93,
#    'pressure': 1009,
#    'humidity': 80,
#    'dew_point': 297.55,
#    'uvi': 3.97,
#    'clouds': 83,
#    'visibility': 10000,
#    'wind_speed': 7.91,
#    'wind_deg': 250,
#    'wind_gust': 9.84,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.98,
#    'rain': {'1h': 0.86}},
#   {'dt': 1718103600,
#    'temp': 301.12,
#    'feels_like': 305.48,
#    'pressure': 1010,
#    'humidity': 82,
#    'dew_point': 297.61,
#    'uvi': 1.55,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 7.69,
#    'wind_deg': 249,
#    'wind_gust': 10.03,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.98,
#    'rain': {'1h': 1.02}},
#   {'dt': 1718107200,
#    'temp': 300.78,
#    'feels_like': 304.75,
#    'pressure': 1010,
#    'humidity': 83,
#    'dew_point': 297.49,
#    'uvi': 0.34,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 7.37,
#    'wind_deg': 252,
#    'wind_gust': 9.88,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.98,
#    'rain': {'1h': 1.05}},
#   {'dt': 1718110800,
#    'temp': 300.53,
#    'feels_like': 304.11,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 297.33,
#    'uvi': 0,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 7.44,
#    'wind_deg': 253,
#    'wind_gust': 10.08,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.96,
#    'rain': {'1h': 1.38}},
#   {'dt': 1718114400,
#    'temp': 300.42,
#    'feels_like': 303.95,
#    'pressure': 1012,
#    'humidity': 84,
#    'dew_point': 297.33,
#    'uvi': 0,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 7.16,
#    'wind_deg': 253,
#    'wind_gust': 9.82,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.97,
#    'rain': {'1h': 1.22}},
#   {'dt': 1718118000,
#    'temp': 300.45,
#    'feels_like': 303.91,
#    'pressure': 1012,
#    'humidity': 83,
#    'dew_point': 297.18,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 7.21,
#    'wind_deg': 250,
#    'wind_gust': 9.97,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.97,
#    'rain': {'1h': 0.92}},
#   {'dt': 1718121600,
#    'temp': 300.56,
#    'feels_like': 304.06,
#    'pressure': 1013,
#    'humidity': 82,
#    'dew_point': 297.19,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 6.82,
#    'wind_deg': 249,
#    'wind_gust': 9.65,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.98,
#    'rain': {'1h': 0.53}},
#   {'dt': 1718125200,
#    'temp': 300.54,
#    'feels_like': 304.13,
#    'pressure': 1013,
#    'humidity': 83,
#    'dew_point': 297.38,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 6.52,
#    'wind_deg': 246,
#    'wind_gust': 9.31,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.95,
#    'rain': {'1h': 0.57}},
#   {'dt': 1718128800,
#    'temp': 300.44,
#    'feels_like': 303.88,
#    'pressure': 1012,
#    'humidity': 83,
#    'dew_point': 297.34,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 6.71,
#    'wind_deg': 246,
#    'wind_gust': 9.49,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.95,
#    'rain': {'1h': 0.89}},
#   {'dt': 1718132400,
#    'temp': 300.45,
#    'feels_like': 303.91,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 297.21,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.77,
#    'wind_deg': 246,
#    'wind_gust': 9.42,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.73,
#    'rain': {'1h': 1.01}},
#   {'dt': 1718136000,
#    'temp': 300.38,
#    'feels_like': 303.74,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 297.19,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.7,
#    'wind_deg': 251,
#    'wind_gust': 9.38,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.7,
#    'rain': {'1h': 0.55}},
#   {'dt': 1718139600,
#    'temp': 300.42,
#    'feels_like': 303.84,
#    'pressure': 1010,
#    'humidity': 83,
#    'dew_point': 297.22,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.74,
#    'wind_deg': 248,
#    'wind_gust': 9.31,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.76,
#    'rain': {'1h': 0.91}},
#   {'dt': 1718143200,
#    'temp': 300.39,
#    'feels_like': 303.76,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 297.17,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 9883,
#    'wind_speed': 6.55,
#    'wind_deg': 247,
#    'wind_gust': 9.26,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.8,
#    'rain': {'1h': 1.21}},
#   {'dt': 1718146800,
#    'temp': 300.46,
#    'feels_like': 303.93,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 297.28,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.99,
#    'wind_deg': 252,
#    'wind_gust': 9.97,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.83,
#    'rain': {'1h': 1.16}},
#   {'dt': 1718150400,
#    'temp': 300.44,
#    'feels_like': 303.88,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 297.23,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 7415,
#    'wind_speed': 7.32,
#    'wind_deg': 254,
#    'wind_gust': 10.22,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.8,
#    'rain': {'1h': 1.49}},
#   {'dt': 1718154000,
#    'temp': 300.56,
#    'feels_like': 304.18,
#    'pressure': 1012,
#    'humidity': 83,
#    'dew_point': 297.24,
#    'uvi': 0.13,
#    'clouds': 100,
#    'visibility': 5988,
#    'wind_speed': 7.72,
#    'wind_deg': 263,
#    'wind_gust': 10.61,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.95,
#    'rain': {'1h': 1.26}},
#   {'dt': 1718157600,
#    'temp': 300.67,
#    'feels_like': 304.33,
#    'pressure': 1013,
#    'humidity': 82,
#    'dew_point': 297.19,
#    'uvi': 0.78,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.94,
#    'wind_deg': 264,
#    'wind_gust': 10.43,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.88,
#    'rain': {'1h': 1.47}},
#   {'dt': 1718161200,
#    'temp': 301.01,
#    'feels_like': 304.9,
#    'pressure': 1013,
#    'humidity': 80,
#    'dew_point': 297.08,
#    'uvi': 2.24,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.02,
#    'wind_deg': 262,
#    'wind_gust': 9.27,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.88,
#    'rain': {'1h': 0.59}},
#   {'dt': 1718164800,
#    'temp': 301.25,
#    'feels_like': 305.34,
#    'pressure': 1013,
#    'humidity': 79,
#    'dew_point': 297.14,
#    'uvi': 5.18,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.19,
#    'wind_deg': 260,
#    'wind_gust': 8.25,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.85,
#    'rain': {'1h': 0.45}},
#   {'dt': 1718168400,
#    'temp': 301.37,
#    'feels_like': 305.31,
#    'pressure': 1013,
#    'humidity': 77,
#    'dew_point': 297.02,
#    'uvi': 7.23,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.11,
#    'wind_deg': 259,
#    'wind_gust': 7.77,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.84,
#    'rain': {'1h': 0.32}},
#   {'dt': 1718172000,
#    'temp': 301.49,
#    'feels_like': 305.77,
#    'pressure': 1012,
#    'humidity': 78,
#    'dew_point': 297.12,
#    'uvi': 5.08,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.83,
#    'wind_deg': 260,
#    'wind_gust': 7.44,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.77,
#    'rain': {'1h': 0.18}},
#   {'dt': 1718175600,
#    'temp': 301.63,
#    'feels_like': 305.77,
#    'pressure': 1012,
#    'humidity': 76,
#    'dew_point': 297.03,
#    'uvi': 4.23,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.89,
#    'wind_deg': 253,
#    'wind_gust': 7.26,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.45,
#    'rain': {'1h': 0.14}},
#   {'dt': 1718179200,
#    'temp': 301.7,
#    'feels_like': 306.11,
#    'pressure': 1011,
#    'humidity': 77,
#    'dew_point': 297.2,
#    'uvi': 5.41,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 6.48,
#    'wind_deg': 255,
#    'wind_gust': 7.86,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.54,
#    'rain': {'1h': 0.5}},
#   {'dt': 1718182800,
#    'temp': 301.29,
#    'feels_like': 305.44,
#    'pressure': 1011,
#    'humidity': 79,
#    'dew_point': 297.25,
#    'uvi': 5.07,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 6.35,
#    'wind_deg': 257,
#    'wind_gust': 7.87,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.8,
#    'rain': {'1h': 1.16}},
#   {'dt': 1718186400,
#    'temp': 301.08,
#    'feels_like': 305.23,
#    'pressure': 1010,
#    'humidity': 81,
#    'dew_point': 297.47,
#    'uvi': 2.46,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 5.99,
#    'wind_deg': 259,
#    'wind_gust': 7.63,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.81,
#    'rain': {'1h': 0.97}},
#   {'dt': 1718190000,
#    'temp': 301.07,
#    'feels_like': 305.35,
#    'pressure': 1011,
#    'humidity': 82,
#    'dew_point': 297.59,
#    'uvi': 0.79,
#    'clouds': 97,
#    'visibility': 8381,
#    'wind_speed': 6,
#    'wind_deg': 257,
#    'wind_gust': 7.71,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.84,
#    'rain': {'1h': 0.71}},
#   {'dt': 1718193600,
#    'temp': 300.58,
#    'feels_like': 304.24,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 297.41,
#    'uvi': 0.18,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 5.55,
#    'wind_deg': 260,
#    'wind_gust': 7.46,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.84,
#    'rain': {'1h': 0.87}},
#   {'dt': 1718197200,
#    'temp': 300.36,
#    'feels_like': 303.8,
#    'pressure': 1012,
#    'humidity': 84,
#    'dew_point': 297.33,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.17,
#    'wind_deg': 257,
#    'wind_gust': 7.3,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.75,
#    'rain': {'1h': 0.71}},
#   {'dt': 1718200800,
#    'temp': 300.14,
#    'feels_like': 303.35,
#    'pressure': 1012,
#    'humidity': 85,
#    'dew_point': 297.31,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.06,
#    'wind_deg': 259,
#    'wind_gust': 7.02,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.82,
#    'rain': {'1h': 0.71}},
#   {'dt': 1718204400,
#    'temp': 300.08,
#    'feels_like': 303.2,
#    'pressure': 1013,
#    'humidity': 85,
#    'dew_point': 297.25,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 4.99,
#    'wind_deg': 260,
#    'wind_gust': 6.93,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.81,
#    'rain': {'1h': 0.65}},
#   {'dt': 1718208000,
#    'temp': 300.07,
#    'feels_like': 303.17,
#    'pressure': 1013,
#    'humidity': 85,
#    'dew_point': 297.35,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 5.33,
#    'wind_deg': 257,
#    'wind_gust': 7.15,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.81,
#    'rain': {'1h': 0.47}},
#   {'dt': 1718211600,
#    'temp': 300.03,
#    'feels_like': 303.17,
#    'pressure': 1013,
#    'humidity': 86,
#    'dew_point': 297.32,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 5.6,
#    'wind_deg': 259,
#    'wind_gust': 7.52,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.85,
#    'rain': {'1h': 0.59}},
#   {'dt': 1718215200,
#    'temp': 300,
#    'feels_like': 303.09,
#    'pressure': 1013,
#    'humidity': 86,
#    'dew_point': 297.27,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 5.9,
#    'wind_deg': 263,
#    'wind_gust': 8.1,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.85,
#    'rain': {'1h': 0.66}},
#   {'dt': 1718218800,
#    'temp': 299.94,
#    'feels_like': 302.85,
#    'pressure': 1012,
#    'humidity': 85,
#    'dew_point': 297.2,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 6.19,
#    'wind_deg': 265,
#    'wind_gust': 8.88,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.97,
#    'rain': {'1h': 0.65}}],
#  'daily': [{'dt': 1718087400,
#    'sunrise': 1718065515,
#    'sunset': 1718110433,
#    'moonrise': 1718080500,
#    'moonset': 1718126040,
#    'moon_phase': 0.16,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 301.93,
#     'min': 300.42,
#     'max': 302.11,
#     'night': 300.44,
#     'eve': 300.78,
#     'morn': 300.83},
#    'feels_like': {'day': 307.08,
#     'night': 303.88,
#     'eve': 304.75,
#     'morn': 304.88},
#    'pressure': 1011,
#    'humidity': 79,
#    'dew_point': 297.8,
#    'wind_speed': 8.33,
#    'wind_deg': 252,
#    'wind_gust': 10.23,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 66,
#    'pop': 0.98,
#    'rain': 14.87,
#    'uvi': 11.52},
#   {'dt': 1718173800,
#    'sunrise': 1718151925,
#    'sunset': 1718196847,
#    'moonrise': 1718169720,
#    'moonset': 1718214900,
#    'moon_phase': 0.19,
#    'summary': 'There will be rain today',
#    'temp': {'day': 301.49,
#     'min': 300,
#     'max': 301.7,
#     'night': 300,
#     'eve': 300.58,
#     'morn': 300.44},
#    'feels_like': {'day': 305.77,
#     'night': 303.09,
#     'eve': 304.24,
#     'morn': 303.88},
#    'pressure': 1012,
#    'humidity': 78,
#    'dew_point': 297.12,
#    'wind_speed': 7.94,
#    'wind_deg': 264,
#    'wind_gust': 10.61,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.95,
#    'rain': 18.74,
#    'uvi': 7.23},
#   {'dt': 1718260200,
#    'sunrise': 1718238335,
#    'sunset': 1718283260,
#    'moonrise': 1718258820,
#    'moonset': 0,
#    'moon_phase': 0.22,
#    'summary': 'There will be rain today',
#    'temp': {'day': 301.9,
#     'min': 299.79,
#     'max': 301.9,
#     'night': 300.05,
#     'eve': 301.06,
#     'morn': 299.96},
#    'feels_like': {'day': 306.81,
#     'night': 303.12,
#     'eve': 305.17,
#     'morn': 302.9},
#    'pressure': 1012,
#    'humidity': 78,
#    'dew_point': 297.66,
#    'wind_speed': 7.51,
#    'wind_deg': 264,
#    'wind_gust': 9.21,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 95,
#    'pop': 0.97,
#    'rain': 11.11,
#    'uvi': 10.71},
#   {'dt': 1718346600,
#    'sunrise': 1718324745,
#    'sunset': 1718369674,
#    'moonrise': 1718347680,
#    'moonset': 1718303520,
#    'moon_phase': 0.25,
#    'summary': 'There will be rain today',
#    'temp': {'day': 301.8,
#     'min': 299.96,
#     'max': 301.8,
#     'night': 300.24,
#     'eve': 300.97,
#     'morn': 299.99},
#    'feels_like': {'day': 306.55,
#     'night': 303.5,
#     'eve': 304.95,
#     'morn': 302.89},
#    'pressure': 1010,
#    'humidity': 78,
#    'dew_point': 297.65,
#    'wind_speed': 7.46,
#    'wind_deg': 268,
#    'wind_gust': 9.45,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 78,
#    'pop': 0.63,
#    'rain': 15.62,
#    'uvi': 11.55},
#   {'dt': 1718433000,
#    'sunrise': 1718411156,
#    'sunset': 1718456087,
#    'moonrise': 1718436600,
#    'moonset': 1718392140,
#    'moon_phase': 0.28,
#    'summary': 'There will be rain today',
#    'temp': {'day': 301.63,
#     'min': 299.94,
#     'max': 301.7,
#     'night': 300.03,
#     'eve': 300.79,
#     'morn': 299.94},
#    'feels_like': {'day': 306.12, 'night': 302.89, 'eve': 304.5, 'morn': 302.6},
#    'pressure': 1010,
#    'humidity': 78,
#    'dew_point': 297.47,
#    'wind_speed': 7.08,
#    'wind_deg': 262,
#    'wind_gust': 9.7,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 86,
#    'pop': 0.97,
#    'rain': 20.58,
#    'uvi': 10.82},
#   {'dt': 1718519400,
#    'sunrise': 1718497566,
#    'sunset': 1718542501,
#    'moonrise': 1718525520,
#    'moonset': 1718480700,
#    'moon_phase': 0.31,
#    'summary': 'There will be rain today',
#    'temp': {'day': 301.78,
#     'min': 299.84,
#     'max': 301.78,
#     'night': 300.22,
#     'eve': 300.64,
#     'morn': 300.06},
#    'feels_like': {'day': 306.31,
#     'night': 303.35,
#     'eve': 304.26,
#     'morn': 302.96},
#    'pressure': 1010,
#    'humidity': 77,
#    'dew_point': 297.28,
#    'wind_speed': 7.05,
#    'wind_deg': 267,
#    'wind_gust': 8.88,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.87,
#    'rain': 12.35,
#    'uvi': 11},
#   {'dt': 1718605800,
#    'sunrise': 1718583978,
#    'sunset': 1718628914,
#    'moonrise': 1718614500,
#    'moonset': 1718569380,
#    'moon_phase': 0.34,
#    'summary': 'There will be rain today',
#    'temp': {'day': 301.54,
#     'min': 299.82,
#     'max': 301.54,
#     'night': 300.29,
#     'eve': 301.05,
#     'morn': 299.82},
#    'feels_like': {'day': 306.07, 'night': 303.31, 'eve': 305, 'morn': 302.48},
#    'pressure': 1010,
#    'humidity': 79,
#    'dew_point': 297.41,
#    'wind_speed': 6.81,
#    'wind_deg': 267,
#    'wind_gust': 8.51,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.91,
#    'rain': 10.11,
#    'uvi': 11},
#   {'dt': 1718692200,
#    'sunrise': 1718670389,
#    'sunset': 1718715327,
#    'moonrise': 1718703720,
#    'moonset': 1718658120,
#    'moon_phase': 0.37,
#    'summary': 'There will be rain until morning, then partly cloudy',
#    'temp': {'day': 302.11,
#     'min': 300,
#     'max': 302.11,
#     'night': 300.4,
#     'eve': 301.24,
#     'morn': 300},
#    'feels_like': {'day': 305.97,
#     'night': 303.79,
#     'eve': 305.16,
#     'morn': 302.56},
#    'pressure': 1010,
#    'humidity': 71,
#    'dew_point': 296.34,
#    'wind_speed': 5.76,
#    'wind_deg': 273,
#    'wind_gust': 7.46,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.35,
#    'rain': 0.43,
#    'uvi': 11}]}
