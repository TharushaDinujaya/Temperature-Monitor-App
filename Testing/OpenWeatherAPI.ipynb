# %%
import requests

# %%
api_url = 'https://api.openweathermap.org/data/3.0/onecall?lat=6.23&lon=80.05&appid=59632c44384fd3104ed01ce7f3510d50'

# %%
response = requests.get(api_url)

# %%
response.json()
# Out:
# {'lat': 6.23,
#  'lon': 80.05,
#  'timezone': 'Asia/Colombo',
#  'timezone_offset': 19800,
#  'current': {'dt': 1717576127,
#   'sunrise': 1717547067,
#   'sunset': 1717591950,
#   'temp': 302.26,
#   'feels_like': 306.71,
#   'pressure': 1011,
#   'humidity': 73,
#   'dew_point': 296.92,
#   'uvi': 8.91,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 4.66,
#   'wind_deg': 216,
#   'wind_gust': 4.94,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1717576140, 'precipitation': 0},
#   {'dt': 1717576200, 'precipitation': 0},
#   {'dt': 1717576260, 'precipitation': 0},
#   {'dt': 1717576320, 'precipitation': 0},
#   {'dt': 1717576380, 'precipitation': 0},
#   {'dt': 1717576440, 'precipitation': 0},
#   {'dt': 1717576500, 'precipitation': 0},
#   {'dt': 1717576560, 'precipitation': 0},
#   {'dt': 1717576620, 'precipitation': 0},
#   {'dt': 1717576680, 'precipitation': 0},
# ...
